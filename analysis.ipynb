# %% [markdown]
# # Supernova Distance Analysis
#
# This notebook will be used to explore the `SNe data.csv` dataset and document intermediate results for the distance conversion work.

# %%
import pandas as pd
import numpy as np

DATA_PATH = "SNe data.csv"

# Placeholder: load the dataset to confirm notebook wiring
try:
    sne_df = pd.read_csv(DATA_PATH)
    sne_df.head()
except FileNotFoundError:
    raise FileNotFoundError(f"Could not find {DATA_PATH}. Make sure the file exists in the repo root.")
